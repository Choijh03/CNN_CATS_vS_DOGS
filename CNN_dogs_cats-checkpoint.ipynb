# %% [markdown]
# #Installing dependencies and libraries

# %%
# !pip install tensorflow tensorflow-gpu opencv-python matplotlib
# Out:
# Requirement already satisfied: tensorflow in c:\users\pc\anaconda3\lib\site-packages (2.10.0)
# Requirement already satisfied: tensorflow-gpu in c:\users\pc\anaconda3\lib\site-packages (2.10.0)
# Requirement already satisfied: opencv-python in c:\users\pc\anaconda3\lib\site-packages (4.6.0.66)
# Requirement already satisfied: matplotlib in c:\users\pc\anaconda3\lib\site-packages (3.5.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\pc\anaconda3\lib\site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\pc\anaconda3\lib\site-packages (from tensorflow) (1.12.1)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\pc\anaconda3\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\pc\anaconda3\lib\site-packages (from tensorflow) (1.42.0)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\pc\anaconda3\lib\site-packages (from tensorflow) (2.0.7)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in c:\users\pc\anaconda3\lib\site-packages (from tensorflow) (1.1.2)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\pc\anaconda3\lib\site-packages (from tensorflow) (1.2.0)
# Requirement already satisfied: numpy>=1.20 in c:\users\pc\anaconda3\lib\site-packages (from tensorflow) (1.21.5)
# Requirement already satisfied: tensorboard<2.11,>=2.10 in c:\users\pc\anaconda3\lib\site-packages (from tensorflow) (2.10.0)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in c:\users\pc\anaconda3\lib\site-packages (from tensorflow) (3.19.1)
# Requirement already satisfied: packaging in c:\users\pc\anaconda3\lib\site-packages (from tensorflow) (21.3)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\pc\anaconda3\lib\site-packages (from tensorflow) (0.27.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\pc\anaconda3\lib\site-packages (from tensorflow) (2.0.1)
# Requirement already satisfied: tensorflow-estimator<2.11,>=2.10.0 in c:\users\pc\anaconda3\lib\site-packages (from tensorflow) (2.10.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\pc\anaconda3\lib\site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: setuptools in c:\users\pc\anaconda3\lib\site-packages (from tensorflow) (61.2.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\pc\anaconda3\lib\site-packages (from tensorflow) (4.1.1)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\pc\anaconda3\lib\site-packages (from tensorflow) (14.0.6)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\pc\anaconda3\lib\site-packages (from tensorflow) (3.6.0)
# Requirement already satisfied: keras<2.11,>=2.10.0 in c:\users\pc\anaconda3\lib\site-packages (from tensorflow) (2.10.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\pc\anaconda3\lib\site-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\pc\anaconda3\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\pc\anaconda3\lib\site-packages (from matplotlib) (3.0.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\pc\anaconda3\lib\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\pc\anaconda3\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\pc\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\pc\anaconda3\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\pc\anaconda3\lib\site-packages (from matplotlib) (9.0.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\pc\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.37.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\pc\anaconda3\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (0.6.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\pc\anaconda3\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (0.4.6)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\pc\anaconda3\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (2.27.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\pc\anaconda3\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (1.8.1)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\pc\anaconda3\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (3.3.4)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\pc\anaconda3\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (1.33.0)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\pc\anaconda3\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (2.0.3)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\pc\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow) (4.7.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\pc\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\users\pc\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow) (4.2.2)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\pc\anaconda3\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow) (1.3.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\pc\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow) (0.4.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\pc\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow) (1.26.9)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\pc\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\pc\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\pc\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow) (2.0.4)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\pc\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow) (3.2.1)

# %%
# !pip list
# Out:
# Package                       Version
# ----------------------------- --------------------
# absl-py                       1.2.0
# aiohttp                       3.8.1
# aiosignal                     1.2.0
# alabaster                     0.7.12
# anaconda-client               1.9.0
# anaconda-navigator            2.1.4
# anaconda-project              0.10.2
# anyio                         3.5.0
# appdirs                       1.4.4
# argon2-cffi                   21.3.0
# argon2-cffi-bindings          21.2.0
# arrow                         1.2.2
# astroid                       2.6.6
# astropy                       5.0.4
# asttokens                     2.0.5
# astunparse                    1.6.3
# async-timeout                 4.0.1
# atomicwrites                  1.4.0
# attrs                         21.4.0
# Automat                       20.2.0
# autopep8                      1.6.0
# Babel                         2.9.1
# backcall                      0.2.0
# backports.functools-lru-cache 1.6.4
# backports.tempfile            1.0
# backports.weakref             1.0.post1
# bcrypt                        3.2.0
# beautifulsoup4                4.11.1
# binaryornot                   0.4.4
# bitarray                      2.4.1
# bkcharts                      0.2
# black                         19.10b0
# bleach                        4.1.0
# bokeh                         2.4.2
# boto3                         1.21.32
# botocore                      1.24.32
# Bottleneck                    1.3.4
# brotlipy                      0.7.0
# cachetools                    4.2.2
# certifi                       2021.10.8
# cffi                          1.15.0
# chardet                       4.0.0
# charset-normalizer            2.0.4
# click                         8.0.4
# cloudpickle                   2.0.0
# clyent                        1.2.2
# colorama                      0.4.4
# colorcet                      2.0.6
# comtypes                      1.1.10
# conda                         4.12.0
# conda-build                   3.21.8
# conda-content-trust           0+unknown
# conda-pack                    0.6.0
# conda-package-handling        1.8.1
# conda-repo-cli                1.0.4
# conda-token                   0.3.0
# conda-verify                  3.4.2
# constantly                    15.1.0
# cookiecutter                  1.7.3
# cryptography                  3.4.8
# cssselect                     1.1.0
# cycler                        0.11.0
# Cython                        0.29.28
# cytoolz                       0.11.0
# daal4py                       2021.5.0
# dask                          2022.2.1
# datashader                    0.13.0
# datashape                     0.5.4
# debugpy                       1.5.1
# decorator                     5.1.1
# defusedxml                    0.7.1
# diff-match-patch              20200713
# distributed                   2022.2.1
# docutils                      0.17.1
# entrypoints                   0.4
# et-xmlfile                    1.1.0
# executing                     0.8.3
# fastjsonschema                2.15.1
# filelock                      3.6.0
# flake8                        3.9.2
# Flask                         1.1.2
# flatbuffers                   2.0.7
# fonttools                     4.25.0
# frozenlist                    1.2.0
# fsspec                        2022.2.0
# future                        0.18.2
# gast                          0.4.0
# gensim                        4.1.2
# glob2                         0.7
# google-api-core               1.25.1
# google-auth                   1.33.0
# google-auth-oauthlib          0.4.6
# google-cloud-core             1.7.1
# google-cloud-storage          1.31.0
# google-crc32c                 1.1.2
# google-pasta                  0.2.0
# google-resumable-media        1.3.1
# googleapis-common-protos      1.53.0
# greenlet                      1.1.1
# grpcio                        1.42.0
# h5py                          3.6.0
# HeapDict                      1.0.1
# holoviews                     1.14.8
# hvplot                        0.7.3
# hyperlink                     21.0.0
# idna                          3.3
# imagecodecs                   2021.8.26
# imageio                       2.9.0
# imagesize                     1.3.0
# importlib-metadata            4.11.3
# incremental                   21.3.0
# inflection                    0.5.1
# iniconfig                     1.1.1
# intake                        0.6.5
# intervaltree                  3.1.0
# ipykernel                     6.9.1
# ipython                       8.2.0
# ipython-genutils              0.2.0
# ipywidgets                    7.6.5
# isort                         5.9.3
# itemadapter                   0.3.0
# itemloaders                   1.0.4
# itsdangerous                  2.0.1
# jdcal                         1.4.1
# jedi                          0.18.1
# Jinja2                        2.11.3
# jinja2-time                   0.2.0
# jmespath                      0.10.0
# joblib                        1.1.0
# json5                         0.9.6
# jsonschema                    4.4.0
# jupyter                       1.0.0
# jupyter-client                6.1.12
# jupyter-console               6.4.0
# jupyter-core                  4.9.2
# jupyter-server                1.13.5
# jupyterlab                    3.3.2
# jupyterlab-pygments           0.1.2
# jupyterlab-server             2.10.3
# jupyterlab-widgets            1.0.0
# keras                         2.10.0
# Keras-Preprocessing           1.1.2
# keyring                       23.4.0
# kiwisolver                    1.3.2
# lazy-object-proxy             1.6.0
# libarchive-c                  2.9
# libclang                      14.0.6
# llvmlite                      0.38.0
# locket                        0.2.1
# lxml                          4.8.0
# Markdown                      3.3.4
# MarkupSafe                    2.0.1
# matplotlib                    3.5.1
# matplotlib-inline             0.1.2
# mccabe                        0.6.1
# menuinst                      1.4.18
# mistune                       0.8.4
# mkl-fft                       1.3.1
# mkl-random                    1.2.2
# mkl-service                   2.4.0
# mock                          4.0.3
# mpmath                        1.2.1
# msgpack                       1.0.2
# multidict                     5.1.0
# multipledispatch              0.6.0
# munkres                       1.1.4
# mypy-extensions               0.4.3
# navigator-updater             0.2.1
# nbclassic                     0.3.5
# nbclient                      0.5.13
# nbconvert                     6.4.4
# nbformat                      5.3.0
# nest-asyncio                  1.5.5
# networkx                      2.7.1
# nltk                          3.7
# nose                          1.3.7
# notebook                      6.4.8
# numba                         0.55.1
# numexpr                       2.8.1
# numpy                         1.21.5
# numpydoc                      1.2
# oauthlib                      3.2.1
# olefile                       0.46
# opencv-python                 4.6.0.66
# openpyxl                      3.0.9
# opt-einsum                    3.3.0
# packaging                     21.3
# pandas                        1.4.2
# pandocfilters                 1.5.0
# panel                         0.13.0
# param                         1.12.0
# paramiko                      2.8.1
# parsel                        1.6.0
# parso                         0.8.3
# partd                         1.2.0
# pathspec                      0.7.0
# patsy                         0.5.2
# pep8                          1.7.1
# pexpect                       4.8.0
# pickleshare                   0.7.5
# Pillow                        9.0.1
# pip                           21.2.4
# pkginfo                       1.8.2
# plotly                        5.6.0
# pluggy                        1.0.0
# poyo                          0.5.0
# prometheus-client             0.13.1
# prompt-toolkit                3.0.20
# Protego                       0.1.16
# protobuf                      3.19.1
# psutil                        5.8.0
# ptyprocess                    0.7.0
# pure-eval                     0.2.2
# py                            1.11.0
# pyasn1                        0.4.8
# pyasn1-modules                0.2.8
# pycodestyle                   2.7.0
# pycosat                       0.6.3
# pycparser                     2.21
# pyct                          0.4.6
# pycurl                        7.44.1
# PyDispatcher                  2.0.5
# pydocstyle                    6.1.1
# pyerfa                        2.0.0
# pyflakes                      2.3.1
# Pygments                      2.11.2
# PyHamcrest                    2.0.2
# PyJWT                         2.1.0
# pylint                        2.9.6
# pyls-spyder                   0.4.0
# PyNaCl                        1.4.0
# pyodbc                        4.0.32
# pyOpenSSL                     21.0.0
# pyparsing                     3.0.4
# pyreadline                    2.1
# pyrsistent                    0.18.0
# PySocks                       1.7.1
# pytest                        7.1.1
# python-dateutil               2.8.2
# python-lsp-black              1.0.0
# python-lsp-jsonrpc            1.0.0
# python-lsp-server             1.2.4
# python-slugify                5.0.2
# python-snappy                 0.6.0
# pytz                          2021.3
# pyviz-comms                   2.0.2
# PyWavelets                    1.3.0
# pywin32                       302
# pywin32-ctypes                0.2.0
# pywinpty                      2.0.2
# PyYAML                        6.0
# pyzmq                         22.3.0
# QDarkStyle                    3.0.2
# qstylizer                     0.1.10
# QtAwesome                     1.0.3
# qtconsole                     5.3.0
# QtPy                          2.0.1
# queuelib                      1.5.0
# regex                         2022.3.15
# requests                      2.27.1
# requests-file                 1.5.1
# requests-oauthlib             1.3.1
# rope                          0.22.0
# rsa                           4.7.2
# Rtree                         0.9.7
# ruamel-yaml-conda             0.15.100
# s3transfer                    0.5.0
# scikit-image                  0.19.2
# scikit-learn                  1.0.2
# scikit-learn-intelex          2021.20220215.102710
# scipy                         1.7.3
# Scrapy                        2.6.1
# seaborn                       0.11.2
# Send2Trash                    1.8.0
# service-identity              18.1.0
# setuptools                    61.2.0
# sip                           4.19.13
# six                           1.16.0
# smart-open                    5.1.0
# sniffio                       1.2.0
# snowballstemmer               2.2.0
# sortedcollections             2.1.0
# sortedcontainers              2.4.0
# soupsieve                     2.3.1
# Sphinx                        4.4.0
# sphinxcontrib-applehelp       1.0.2
# sphinxcontrib-devhelp         1.0.2
# sphinxcontrib-htmlhelp        2.0.0
# sphinxcontrib-jsmath          1.0.1
# sphinxcontrib-qthelp          1.0.3
# sphinxcontrib-serializinghtml 1.1.5
# spyder                        5.1.5
# spyder-kernels                2.1.3
# SQLAlchemy                    1.4.32
# stack-data                    0.2.0
# statsmodels                   0.13.2
# sympy                         1.10.1
# tables                        3.6.1
# tabulate                      0.8.9
# TBB                           0.2
# tblib                         1.7.0
# tenacity                      8.0.1
# tensorboard                   2.10.0
# tensorboard-data-server       0.6.1
# tensorboard-plugin-wit        1.8.1
# tensorflow                    2.10.0
# tensorflow-estimator          2.10.0
# tensorflow-gpu                2.10.0
# tensorflow-io-gcs-filesystem  0.27.0
# termcolor                     2.0.1
# terminado                     0.13.1
# testpath                      0.5.0
# text-unidecode                1.3
# textdistance                  4.2.1
# threadpoolctl                 2.2.0
# three-merge                   0.1.1
# tifffile                      2021.7.2
# tinycss                       0.4
# tldextract                    3.2.0
# toml                          0.10.2
# tomli                         1.2.2
# toolz                         0.11.2
# tornado                       6.1
# tqdm                          4.64.0
# traitlets                     5.1.1
# Twisted                       22.2.0
# twisted-iocpsupport           1.0.2
# typed-ast                     1.4.3
# typing_extensions             4.1.1
# ujson                         5.1.0
# Unidecode                     1.2.0
# urllib3                       1.26.9
# w3lib                         1.21.0
# watchdog                      2.1.6
# wcwidth                       0.2.5
# webencodings                  0.5.1
# websocket-client              0.58.0
# Werkzeug                      2.0.3
# wheel                         0.37.1
# widgetsnbextension            3.5.2
# win-inet-pton                 1.1.0
# win-unicode-console           0.5
# wincertstore                  0.2
# wrapt                         1.12.1
# xarray                        0.20.1
# xlrd                          2.0.1
# XlsxWriter                    3.0.3
# xlwings                       0.24.9
# yapf                          0.31.0
# yarl                          1.6.3
# zict                          2.0.0
# zipp                          3.7.0
# zope.interface                5.4.0

# %%
import tensorflow as tf
import os

# %% [markdown]
# #Data Collection

# %%
import cv2
import imghdr
from matplotlib import pyplot as plt

# %%
data_dir = r'data'

# %%
imgage_exts = ['jpeg','jpg','bmp','png']

# %%
for image_class in os.listdir(data_dir): 
    for image in os.listdir(os.path.join(data_dir, image_class)):
        image_path = os.path.join(data_dir, image_class, image)
        try: 
            img = cv2.imread(image_path)
            tip = imghdr.what(image_path)
            if tip not in image_exts: 
                print('Image not in ext list {}'.format(image_path))
                os.remove(image_path)
        except Exception as e: 
            print('Issue with image {}'.format(image_path))
            # os.remove(image_path)
# Out:
# Issue with image data\cats\02-cat-training-NationalGeographic_1484324_3x4.jpg
# Issue with image data\cats\07CAT-STRIPES-mediumSquareAt3X-v2.jpg
# Issue with image data\cats\107072184-1654616434858-pixel-selfie.jpg
# Issue with image data\cats\1200px-Cat03.jpg
# Issue with image data\cats\1200px-Cat_November_2010-1a.jpg
# Issue with image data\cats\142774.jpg
# Issue with image data\cats\1E3A3E62-B3CA-434A-8C3B3ED0C982FB69_source.jpg
# Issue with image data\cats\2.jpg
# Issue with image data\cats\220726-cat-theo-elise-ew-636p-6cd3b0.jpg
# Issue with image data\cats\32665E6F-8D90-4567-9769D59E11DB7F26_source.jpg
# Issue with image data\cats\344x361_FoundACat.jpg
# Issue with image data\cats\72295960.jpg
# Issue with image data\cats\96b0f8c1fc7546deab323b0f6ba9f33a.jpg
# Issue with image data\cats\Abyssinian-sorrel.jpg
# Issue with image data\cats\animals-cats-cute-45170-min.jpg
# Issue with image data\cats\ap22194581263412_custom-d6464f6438abdb0983fb8c47a51fe2c7dc14.jpg
# Issue with image data\cats\Article Hero- cat health.jpg
# Issue with image data\cats\Banner4.jpg
# Issue with image data\cats\best-girl-cat-names-1606245046.jpg
# Issue with image data\cats\black-cat-gettyimages-901574784.jpg
# Issue with image data\cats\black-footed.jpg
# Issue with image data\cats\calico-cat.jpg
# Issue with image data\cats\cat-217679.jpg
# Issue with image data\cats\Cat-andriyko-podilnyk-RCfi7vgJjUY-unsplash_1659328989095_165.jpg
# Issue with image data\cats\cat-behaviour.jpg
# Issue with image data\cats\cat-black-superstitious-fcs-cat-myths-162286659.jpg
# Issue with image data\cats\cat-landing-hero-sm.jpg
# Issue with image data\cats\cats.jpg
# Issue with image data\cats\cat_on_fence_outside-1324776163.jpg
# Issue with image data\cats\Cat_poster_1.jpg
# Issue with image data\cats\close-up-of-cat-wearing-sunglasses-while-sitting-royalty-fre.jpg
# Issue with image data\cats\cs-pet-health-cat-exercises-1440x810.jpg
# Issue with image data\cats\Culture-Grumpy-Cat-487386121.jpg
# Issue with image data\cats\d41586-022-01792-y_23218332.jpg
# Issue with image data\cats\DCTM_Penguin_UK_DK_AL697473_RGB_PNG_namnse.jpg
# Issue with image data\cats\EBT-L-CATSHOW-0403-11.jpg
# Issue with image data\cats\eff84c687e50d533f210c2582ffd570142-31-cat-food.jpg
# Issue with image data\cats\egypt_kitty_social.jpg
# Issue with image data\cats\file-20200803-24-50u91u.jpg
# Issue with image data\cats\GettyImages-1175550351.jpg
# Issue with image data\cats\gettyimages-1279899488_wide-f3860ceb0ef19643c335cb34df3fa1de.jpg
# Issue with image data\cats\giftsforcats-2048px-catball.jpg
# Issue with image data\cats\h5mk7js_cat-generic_625x300_28_August_20.jpg
# Issue with image data\cats\Himalayan-chocolate-point.jpg
# Issue with image data\cats\Homepage-MiddleBox-768x512.jpg
# Issue with image data\cats\How-Much-Does-It-Cost-to-Have-a-Cat-_-ASPCA-Pet-Insurance-_-.jpg
# Issue with image data\cats\image (13).jpeg
# Issue with image data\cats\image (18).jpeg
# Issue with image data\cats\image (19).jpeg
# Issue with image data\cats\image (25).jpeg
# Issue with image data\cats\image (28).jpeg
# Issue with image data\cats\image (29).jpeg
# Issue with image data\cats\images (103).jpeg
# Issue with image data\cats\images (104).jpeg
# Issue with image data\cats\images (106).jpeg
# Issue with image data\cats\images (108).jpeg
# Issue with image data\cats\images (113).jpeg
# Issue with image data\cats\images (114).jpeg
# Issue with image data\cats\images (116).jpeg
# Issue with image data\cats\images (118).jpeg
# Issue with image data\cats\images (122).jpeg
# Issue with image data\cats\images (123).jpeg
# Issue with image data\cats\images (132).jpeg
# Issue with image data\cats\images (135).jpeg
# Issue with image data\cats\images (140).jpeg
# Issue with image data\cats\images (142).jpeg
# Issue with image data\cats\images (144).jpeg
# Issue with image data\cats\images (145).jpeg
# Issue with image data\cats\images (146).jpeg
# Issue with image data\cats\images (150).jpeg
# Issue with image data\cats\images (151).jpeg
# Issue with image data\cats\images (152).jpeg
# Issue with image data\cats\images (153).jpeg
# Issue with image data\cats\images (157).jpeg
# Issue with image data\cats\images (158).jpeg
# Issue with image data\cats\images (16).jpeg
# Issue with image data\cats\images (164).jpeg
# Issue with image data\cats\images (171).jpeg
# Issue with image data\cats\images (172).jpeg
# Issue with image data\cats\images (173).jpeg
# Issue with image data\cats\images (179).jpeg
# Issue with image data\cats\images (18).jpeg
# Issue with image data\cats\images (181).jpeg
# Issue with image data\cats\images (184).jpeg
# Issue with image data\cats\images (185).jpeg
# Issue with image data\cats\images (187).jpeg
# Issue with image data\cats\images (188).jpeg
# Issue with image data\cats\images (190).jpeg
# Issue with image data\cats\images (193).jpeg
# Issue with image data\cats\images (197).jpeg
# Issue with image data\cats\images (199).jpeg
# Issue with image data\cats\images (202).jpeg
# Issue with image data\cats\images (206).jpeg
# Issue with image data\cats\images (212).jpeg
# Issue with image data\cats\images (213).jpeg
# Issue with image data\cats\images (214).jpeg
# Issue with image data\cats\images (215).jpeg
# Issue with image data\cats\images (219).jpeg
# Issue with image data\cats\images (220).jpeg
# Issue with image data\cats\images (222).jpeg
# Issue with image data\cats\images (223).jpeg
# Issue with image data\cats\images (224).jpeg
# Issue with image data\cats\images (226).jpeg
# Issue with image data\cats\images (227).jpeg
# Issue with image data\cats\images (229).jpeg
# Issue with image data\cats\images (230).jpeg
# Issue with image data\cats\images (231).jpeg
# Issue with image data\cats\images (234).jpeg
# Issue with image data\cats\images (235).jpeg
# Issue with image data\cats\images (239).jpeg
# Issue with image data\cats\images (24).jpeg
# Issue with image data\cats\images (241).jpeg
# Issue with image data\cats\images (245).jpeg
# Issue with image data\cats\images (247).jpeg
# Issue with image data\cats\images (25).jpeg
# Issue with image data\cats\images (250).jpeg
# Issue with image data\cats\images (251).jpeg
# Issue with image data\cats\images (257).jpeg
# Issue with image data\cats\images (258).jpeg
# Issue with image data\cats\images (262).jpeg
# Issue with image data\cats\images (263).jpeg
# Issue with image data\cats\images (268).jpeg
# Issue with image data\cats\images (269).jpeg
# Issue with image data\cats\images (270).jpeg
# Issue with image data\cats\images (271).jpeg
# Issue with image data\cats\images (272).jpeg
# Issue with image data\cats\images (273).jpeg
# Issue with image data\cats\images (276).jpeg
# Issue with image data\cats\images (278).jpeg
# Issue with image data\cats\images (281).jpeg
# Issue with image data\cats\images (285).jpeg
# Issue with image data\cats\images (286).jpeg
# Issue with image data\cats\images (287).jpeg
# Issue with image data\cats\images (29).jpeg
# Issue with image data\cats\images (292).jpeg
# Issue with image data\cats\images (293).jpeg
# Issue with image data\cats\images (30).jpeg
# Issue with image data\cats\images (300).jpeg
# Issue with image data\cats\images (301).jpeg
# Issue with image data\cats\images (304).jpeg
# Issue with image data\cats\images (305).jpeg
# Issue with image data\cats\images (309).jpeg
# Issue with image data\cats\images (314).jpeg
# Issue with image data\cats\images (318).jpeg
# Issue with image data\cats\images (321).jpeg
# Issue with image data\cats\images (322).jpeg
# Issue with image data\cats\images (324).jpeg
# Issue with image data\cats\images (325).jpeg
# Issue with image data\cats\images (328).jpeg
# Issue with image data\cats\images (330).jpeg
# Issue with image data\cats\images (331).jpeg
# Issue with image data\cats\images (334).jpeg
# Issue with image data\cats\images (34).jpeg
# Issue with image data\cats\images (340).jpeg
# Issue with image data\cats\images (341).jpeg
# Issue with image data\cats\images (342).jpeg
# Issue with image data\cats\images (344).jpeg
# Issue with image data\cats\images (347).jpeg
# Issue with image data\cats\images (348).jpeg
# Issue with image data\cats\images (35).jpeg
# Issue with image data\cats\images (351).jpeg
# Issue with image data\cats\images (352).jpeg
# Issue with image data\cats\images (353).jpeg
# Issue with image data\cats\images (355).jpeg
# Issue with image data\cats\images (356).jpeg
# Issue with image data\cats\images (359).jpeg
# Issue with image data\cats\images (362).jpeg
# Issue with image data\cats\images (364).jpeg
# Issue with image data\cats\images (372).jpeg
# Issue with image data\cats\images (375).jpeg
# Issue with image data\cats\images (378).jpeg
# Issue with image data\cats\images (379).jpeg
# Issue with image data\cats\images (381).jpeg
# Issue with image data\cats\images (41).jpeg
# Issue with image data\cats\images (44).jpeg
# Issue with image data\cats\images (53).jpeg
# Issue with image data\cats\images (55).jpeg
# Issue with image data\cats\images (57).jpeg
# Issue with image data\cats\images (59).jpeg
# Issue with image data\cats\images (60).jpeg
# Issue with image data\cats\images (67).jpeg
# Issue with image data\cats\images (69).jpeg
# Issue with image data\cats\images (71).jpeg
# Issue with image data\cats\images (72).jpeg
# Issue with image data\cats\images (73).jpeg
# Issue with image data\cats\images (78).jpeg
# Issue with image data\cats\images (79).jpeg
# Issue with image data\cats\images (83).jpeg
# Issue with image data\cats\images (85).jpeg
# Issue with image data\cats\images (86).jpeg
# Issue with image data\cats\images (88).jpeg
# Issue with image data\cats\images (89).jpeg
# Issue with image data\cats\images (90).jpeg
# Issue with image data\cats\images (91).jpeg
# Issue with image data\cats\images (92).jpeg
# Issue with image data\cats\images (94).jpeg
# Issue with image data\cats\images (97).jpeg
# Issue with image data\cats\interesting-cat-facts.jpg
# Issue with image data\cats\international-cat-day-640x514.jpg
# Issue with image data\cats\iStock-495910314.jpg
# Issue with image data\cats\kitten-510651.jpg
# Issue with image data\cats\Lane-Cats.jpg
# Issue with image data\cats\Layer-1704-1200x630.jpg
# Issue with image data\cats\los-10-sonidos-principales-del-gato-fa.jpg
# Issue with image data\cats\maxresdefault (1).jpg
# Issue with image data\cats\maxresdefault (2).jpg
# Issue with image data\cats\maxresdefault.jpg
# Issue with image data\cats\NationalGeographic_2572187_3x2.jpg
# Issue with image data\cats\Obsessions-How-Cats-Tamed-Us.jpg
# Issue with image data\cats\p07ryyyj.jpg
# Issue with image data\cats\pallas-cat-face-close-up-full-width.jpg
# Issue with image data\cats\portrait-of-cat-sitting-on-sofa-at-home-royalty-free-image-1.jpg
# Issue with image data\cats\PPF-BlogUpdate-Thumbs_0041_42_Cat-Stages.jpg
# Issue with image data\cats\relaxed-ginger-cat.jpg
# Issue with image data\cats\SanFranCatNap_McCarthy.jpg
# Issue with image data\cats\shutterstock_707431309-e1554172878508.jpg
# Issue with image data\cats\taylor-swift-cats.jpg
# Issue with image data\cats\Thinking-of-getting-a-cat.png
# Issue with image data\cats\Transparent-OrangeWhiteCat-764x1024.png
# Issue with image data\cats\VAN_CAT.png
# Issue with image data\cats\XNP4WBVHIBOPVM4OCZ34RP7HRA.jpg
# Issue with image data\cats\_6bda0940-b9ad-11e9-98cb-e738ad509720.jpg
# Issue with image data\dogs\03222022_olddogs13_185338.jpg
# Issue with image data\dogs\102107675-dog-park-bullies-632x475-632x353.jpg
# Issue with image data\dogs\1200px-Labrador_on_Quantock_-2175262184-.jpg
# Issue with image data\dogs\1200x-1.jpg
# Issue with image data\dogs\1FD432BD-1DC9-4EE3-B2F3494EBAE7DCAE_source.jpg
# Issue with image data\dogs\2-dog.jpg
# Issue with image data\dogs\201030094143-stock-rhodesian-ridgeback-super-tease.jpg
# Issue with image data\dogs\20200709-dog.jpg
# Issue with image data\dogs\2022090713384694-3966625540085745215-henry-1-810x540.jpg
# Issue with image data\dogs\220428-dog-breeds-mb-1019-95b354.jpg
# Issue with image data\dogs\220805-border-collie-play-mn-1100-82d2f1.jpg
# Issue with image data\dogs\22xp-dog1-videoSixteenByNine3000.jpg
# Issue with image data\dogs\3180-Pug_green_grass-732x549-thumbnail-732x549.jpg
# Issue with image data\dogs\322868_1100-800x825.jpg
# Issue with image data\dogs\580540_mjznrj.jpg
# Issue with image data\dogs\A1CCF800-9EAD-4FFF-A57B4EE0B4E6CFED_source.jpg
# Issue with image data\dogs\Afghan-Hound-standing-in-a-garden-400x267.jpg
# Issue with image data\dogs\AmericanBullysobakabarobaka-4ce0d4dc0e144dccadb5159b222e275e.jpg
# Issue with image data\dogs\AZ6KPVJTOZMBXFP7KGICZK3SNM.jpg
# Issue with image data\dogs\black-lab-favorite-dog-main-220315-e8e0ee.jpg
# Issue with image data\dogs\cute-dog-headshot.jpg
# Issue with image data\dogs\d41586-022-00209-0_20071824.jpg
# Issue with image data\dogs\dog-451643.jpg
# Issue with image data\dogs\dog-breed-is-not-an-accurate-way-to-predict-behavior-361072-.jpg
# Issue with image data\dogs\dog-care_general-dog-care_main-image.jpg
# Issue with image data\dogs\dog-field.jpg
# Issue with image data\dogs\dog-grass-441879.jpg
# Issue with image data\dogs\dog-puppy-on-garden-royalty-free-image-1586966191.jpg
# Issue with image data\dogs\dog-wearing-tutu-jpeg.jpg
# Issue with image data\dogs\dog.jpg
# Issue with image data\dogs\dogs-1600.jpg
# Issue with image data\dogs\dogs_1280p_0.jpg
# Issue with image data\dogs\Dog_1098119012_Hero.jpg
# Issue with image data\dogs\dog_16x9_3.jpg
# Issue with image data\dogs\dog_230497594.jpg
# Issue with image data\dogs\dog_license.jpg
# Issue with image data\dogs\domestic-dog_thumb_2x3.jpg
# Issue with image data\dogs\domestic-dog_thumb_4x3.jpg
# Issue with image data\dogs\German-shepherd.jpg
# Issue with image data\dogs\GettyImages-1205998407-e1624731290663.jpg
# Issue with image data\dogs\gettyimages-1310156391.jpg
# Issue with image data\dogs\GettyImages-912084898-e1641834261695.jpg
# Issue with image data\dogs\gettyimages-917452888-edit_custom-c656c35e4e40bf22799195af84.jpg
# Issue with image data\dogs\golden-retriever-dog-royalty-free-image-505534037-1565105327.jpg
# Issue with image data\dogs\Golden-Retriever-Puppy.jpg
# Issue with image data\dogs\golden-retriever-royalty-free-image-506756303-1560962726.jpg
# Issue with image data\dogs\Gupta-DogTourofHouse.jpg
# Issue with image data\dogs\HB4AT3D3IMI6TMPTWIZ74WAR54.jpg
# Issue with image data\dogs\https-__cdn-cnn-com_cnnnext_dam_assets_220719101500-keeping-.jpg
# Issue with image data\dogs\husky_eyes.jpg
# Issue with image data\dogs\IJIIFKQ774I63AATSFCLQCU2D4_size-normalized.jpg
# Issue with image data\dogs\image (11).jpeg
# Issue with image data\dogs\image (12).jpeg
# Issue with image data\dogs\image (14).jpeg
# Issue with image data\dogs\image (15).jpeg
# Issue with image data\dogs\image (18).jpeg
# Issue with image data\dogs\image (19).jpeg
# Issue with image data\dogs\image (20).jpeg
# Issue with image data\dogs\image (22).jpeg
# Issue with image data\dogs\image (27).jpeg
# Issue with image data\dogs\image (28).jpeg
# Issue with image data\dogs\imagehywzk.png
# Issue with image data\dogs\images (105).jpeg
# Issue with image data\dogs\images (106).jpeg
# Issue with image data\dogs\images (107).jpeg
# Issue with image data\dogs\images (108).jpeg
# Issue with image data\dogs\images (110).jpeg
# Issue with image data\dogs\images (112).jpeg
# Issue with image data\dogs\images (113).jpeg
# Issue with image data\dogs\images (114).jpeg
# Issue with image data\dogs\images (116).jpeg
# Issue with image data\dogs\images (117).jpeg
# Issue with image data\dogs\images (119).jpeg
# Issue with image data\dogs\images (121).jpeg
# Issue with image data\dogs\images (122).jpeg
# Issue with image data\dogs\images (124).jpeg
# Issue with image data\dogs\images (126).jpeg
# Issue with image data\dogs\images (130).jpeg
# Issue with image data\dogs\images (134).jpeg
# Issue with image data\dogs\images (135).jpeg
# Issue with image data\dogs\images (144).jpeg
# Issue with image data\dogs\images (145).jpeg
# Issue with image data\dogs\images (148).jpeg
# Issue with image data\dogs\images (149).jpeg
# Issue with image data\dogs\images (150).jpeg
# Issue with image data\dogs\images (152).jpeg
# Issue with image data\dogs\images (153).jpeg
# Issue with image data\dogs\images (157).jpeg
# Issue with image data\dogs\images (158).jpeg
# Issue with image data\dogs\images (159).jpeg
# Issue with image data\dogs\images (163).jpeg
# Issue with image data\dogs\images (164).jpeg
# Issue with image data\dogs\images (165).jpeg
# Issue with image data\dogs\images (167).jpeg
# Issue with image data\dogs\images (168).jpeg
# Issue with image data\dogs\images (169).jpeg
# Issue with image data\dogs\images (17).jpeg
# Issue with image data\dogs\images (170).jpeg
# Issue with image data\dogs\images (171).jpeg
# Issue with image data\dogs\images (172).jpeg
# Issue with image data\dogs\images (173).jpeg
# Issue with image data\dogs\images (174).jpeg
# Issue with image data\dogs\images (175).jpeg
# Issue with image data\dogs\images (176).jpeg
# Issue with image data\dogs\images (177).jpeg
# Issue with image data\dogs\images (178).jpeg
# Issue with image data\dogs\images (18).jpeg
# Issue with image data\dogs\images (180).jpeg
# Issue with image data\dogs\images (183).jpeg
# Issue with image data\dogs\images (184).jpeg
# Issue with image data\dogs\images (185).jpeg
# Issue with image data\dogs\images (186).jpeg
# Issue with image data\dogs\images (189).jpeg
# Issue with image data\dogs\images (191).jpeg
# Issue with image data\dogs\images (192).jpeg
# Issue with image data\dogs\images (195).jpeg
# Issue with image data\dogs\images (196).jpeg
# Issue with image data\dogs\images (197).jpeg
# Issue with image data\dogs\images (198).jpeg
# Issue with image data\dogs\images (199).jpeg
# Issue with image data\dogs\images (200).jpeg
# Issue with image data\dogs\images (201).jpeg
# Issue with image data\dogs\images (203).jpeg
# Issue with image data\dogs\images (205).jpeg
# Issue with image data\dogs\images (206).jpeg
# Issue with image data\dogs\images (208).jpeg
# Issue with image data\dogs\images (211).jpeg
# Issue with image data\dogs\images (212).jpeg
# Issue with image data\dogs\images (219).jpeg
# Issue with image data\dogs\images (220).jpeg
# Issue with image data\dogs\images (221).jpeg
# Issue with image data\dogs\images (223).jpeg
# Issue with image data\dogs\images (224).jpeg
# Issue with image data\dogs\images (225).jpeg
# Issue with image data\dogs\images (226).jpeg
# Issue with image data\dogs\images (227).jpeg
# Issue with image data\dogs\images (232).jpeg
# Issue with image data\dogs\images (235).jpeg
# Issue with image data\dogs\images (236).jpeg
# Issue with image data\dogs\images (238).jpeg
# Issue with image data\dogs\images (239).jpeg
# Issue with image data\dogs\images (24).jpeg
# Issue with image data\dogs\images (241).jpeg
# Issue with image data\dogs\images (245).jpeg
# Issue with image data\dogs\images (246).jpeg
# Issue with image data\dogs\images (247).jpeg
# Issue with image data\dogs\images (249).jpeg
# Issue with image data\dogs\images (25).jpeg
# Issue with image data\dogs\images (253).jpeg
# Issue with image data\dogs\images (255).jpeg
# Issue with image data\dogs\images (257).jpeg
# Issue with image data\dogs\images (259).jpeg
# Issue with image data\dogs\images (26).jpeg
# Issue with image data\dogs\images (261).jpeg
# Issue with image data\dogs\images (262).jpeg
# Issue with image data\dogs\images (263).jpeg
# Issue with image data\dogs\images (265).jpeg
# Issue with image data\dogs\images (267).jpeg
# Issue with image data\dogs\images (269).jpeg
# Issue with image data\dogs\images (272).jpeg
# Issue with image data\dogs\images (273).jpeg
# Issue with image data\dogs\images (274).jpeg
# Issue with image data\dogs\images (276).jpeg
# Issue with image data\dogs\images (28).jpeg
# Issue with image data\dogs\images (280).jpeg
# Issue with image data\dogs\images (282).jpeg
# Issue with image data\dogs\images (284).jpeg
# Issue with image data\dogs\images (287).jpeg
# Issue with image data\dogs\images (288).jpeg
# Issue with image data\dogs\images (29).jpeg
# Issue with image data\dogs\images (290).jpeg
# Issue with image data\dogs\images (292).jpeg
# Issue with image data\dogs\images (293).jpeg
# Issue with image data\dogs\images (297).jpeg
# Issue with image data\dogs\images (298).jpeg
# Issue with image data\dogs\images (31).jpeg
# Issue with image data\dogs\images (32).jpeg
# Issue with image data\dogs\images (33).jpeg
# Issue with image data\dogs\images (336).jpeg
# Issue with image data\dogs\images (337).jpeg
# Issue with image data\dogs\images (338).jpeg
# Issue with image data\dogs\images (339).jpeg
# Issue with image data\dogs\images (340).jpeg
# Issue with image data\dogs\images (344).jpeg
# Issue with image data\dogs\images (346).jpeg
# Issue with image data\dogs\images (347).jpeg
# Issue with image data\dogs\images (348).jpeg
# Issue with image data\dogs\images (350).jpeg
# Issue with image data\dogs\images (351).jpeg
# Issue with image data\dogs\images (352).jpeg
# Issue with image data\dogs\images (36).jpeg
# Issue with image data\dogs\images (37).jpeg
# Issue with image data\dogs\images (374).jpeg
# Issue with image data\dogs\images (375).jpeg
# Issue with image data\dogs\images (377).jpeg
# Issue with image data\dogs\images (379).jpeg
# Issue with image data\dogs\images (38).jpeg
# Issue with image data\dogs\images (382).jpeg
# Issue with image data\dogs\images (384).jpeg
# Issue with image data\dogs\images (385).jpeg
# Issue with image data\dogs\images (386).jpeg
# Issue with image data\dogs\images (387).jpeg
# Issue with image data\dogs\images (388).jpeg
# Issue with image data\dogs\images (39).jpeg
# Issue with image data\dogs\images (391).jpeg
# Issue with image data\dogs\images (394).jpeg
# Issue with image data\dogs\images (40).jpeg
# Issue with image data\dogs\images (41).jpeg
# Issue with image data\dogs\images (412).jpeg
# Issue with image data\dogs\images (42).jpeg
# Issue with image data\dogs\images (43).jpeg
# Issue with image data\dogs\images (45).jpeg
# Issue with image data\dogs\images (46).jpeg
# Issue with image data\dogs\images (51).jpeg
# Issue with image data\dogs\images (52).jpeg
# Issue with image data\dogs\images (53).jpeg
# Issue with image data\dogs\images (55).jpeg
# Issue with image data\dogs\images (56).jpeg
# Issue with image data\dogs\images (57).jpeg
# Issue with image data\dogs\images (58).jpeg
# Issue with image data\dogs\images (59).jpeg
# Issue with image data\dogs\images (62).jpeg
# Issue with image data\dogs\images (63).jpeg
# Issue with image data\dogs\images (64).jpeg
# Issue with image data\dogs\images (65).jpeg
# Issue with image data\dogs\images (67).jpeg
# Issue with image data\dogs\images (68).jpeg
# Issue with image data\dogs\images (70).jpeg
# Issue with image data\dogs\images (72).jpeg
# Issue with image data\dogs\images (73).jpeg
# Issue with image data\dogs\images (74).jpeg
# Issue with image data\dogs\images (77).jpeg
# Issue with image data\dogs\images (78).jpeg
# Issue with image data\dogs\images (80).jpeg
# Issue with image data\dogs\images (82).jpeg
# Issue with image data\dogs\images (83).jpeg
# Issue with image data\dogs\images (85).jpeg
# Issue with image data\dogs\images (87).jpeg
# Issue with image data\dogs\images (88).jpeg
# Issue with image data\dogs\images (89).jpeg
# Issue with image data\dogs\images (91).jpeg
# Issue with image data\dogs\images (93).jpeg
# Issue with image data\dogs\images (94).jpeg
# Issue with image data\dogs\images (95).jpeg
# Issue with image data\dogs\images (97).jpeg
# Issue with image data\dogs\images (99).jpeg
# Issue with image data\dogs\_124800859_gettyimages-817514614.jpg

# %% [markdown]
# #Load Images

# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
data = tf.keras.utils.image_dataset_from_directory(data_dir)
# Out:
# Found 469 files belonging to 2 classes.

# %%
data_iterator = data.as_numpy_iterator()

# %%
batch = data_iterator.next()

# %%
fig, ax = plt.subplots(ncols=4, figsize=(20,20))
for idx, img in enumerate(batch[0][:4]):
    ax[idx].imshow(img.astype(int))
    ax[idx].title.set_text(batch[1][idx])

# %% [markdown]
# #Scale Data

# %%
data = data.map(lambda x,y: (x/255, y))

# %%
data.as_numpy_iterator().next()
# Out:
# (array([[[[7.60569843e-03, 7.60569843e-03, 1.54488357e-02],
#           [3.20925238e-03, 3.20925238e-03, 1.10523896e-02],
#           [0.00000000e+00, 0.00000000e+00, 7.84313772e-03],
#           ...,
#           [7.84313772e-03, 7.84313772e-03, 7.84313772e-03],
#           [7.84313772e-03, 7.84313772e-03, 7.84313772e-03],
#           [7.84313772e-03, 7.84313772e-03, 7.84313772e-03]],
#
#          [[9.68903210e-03, 9.68903210e-03, 1.75321698e-02],
#           [4.91416780e-03, 4.91416780e-03, 1.27573051e-02],
#           [0.00000000e+00, 0.00000000e+00, 7.84313772e-03],
#           ...,
#           [7.84313772e-03, 7.84313772e-03, 7.84313772e-03],
#           [7.84313772e-03, 7.84313772e-03, 7.84313772e-03],
#           [7.84313772e-03, 7.84313772e-03, 7.84313772e-03]],
#
#          [[1.23851104e-02, 1.23851104e-02, 2.02282481e-02],
#           [7.27634784e-03, 7.27634784e-03, 1.51194856e-02],
#           [5.98144543e-04, 5.98144543e-04, 8.44128150e-03],
#           ...,
#           [7.84313772e-03, 7.84313772e-03, 7.84313772e-03],
#           [7.84313772e-03, 7.84313772e-03, 7.84313772e-03],
#           [7.84313772e-03, 7.84313772e-03, 7.84313772e-03]],
#
#          ...,
#
#          [[6.90394282e-01, 6.98237419e-01, 6.47257030e-01],
#           [7.19148278e-01, 7.26991415e-01, 6.76011026e-01],
#           [6.23206735e-01, 6.31049871e-01, 5.80069482e-01],
#           ...,
#           [7.27714241e-01, 7.01212347e-01, 6.18438840e-01],
#           [6.35551929e-01, 6.15075946e-01, 5.30672908e-01],
#           [5.73697686e-01, 5.54089844e-01, 4.67919201e-01]],
#
#          [[6.43709540e-01, 6.51552677e-01, 6.00572288e-01],
#           [6.89111352e-01, 6.96954489e-01, 6.45974100e-01],
#           [6.24971509e-01, 6.32814646e-01, 5.81834257e-01],
#           ...,
#           [6.88822210e-01, 6.64031386e-01, 5.78387558e-01],
#           [6.64800882e-01, 6.44480765e-01, 5.58206260e-01],
#           [5.94273210e-01, 5.79846203e-01, 4.91844743e-01]],
#
#          [[5.92509210e-01, 6.00352347e-01, 5.49371958e-01],
#           [6.53124988e-01, 6.60968125e-01, 6.09987736e-01],
#           [6.19140625e-01, 6.26983762e-01, 5.76003373e-01],
#
#          ...,
#
#          [[6.79536223e-01, 7.93367505e-01, 4.87137139e-01],
#           [6.91026628e-01, 7.97594011e-01, 4.85548794e-01],
#           [7.34021723e-01, 8.29526186e-01, 5.15314817e-01],
#           ...,
#           [5.78860283e-01, 6.51386797e-01, 5.17877817e-01],
#           [4.03770775e-01, 5.20395815e-01, 3.38257313e-01],
#           [3.44407260e-01, 4.88923192e-01, 2.77236521e-01]],
#
#          [[7.67103732e-01, 8.70678246e-01, 5.94085097e-01],
#           [7.38453090e-01, 8.37258279e-01, 5.50921023e-01],
#           [7.93619335e-01, 8.83745492e-01, 5.83149970e-01],
#           ...,
#           [5.06482661e-01, 5.74985147e-01, 4.47729021e-01],
#           [3.34983438e-01, 4.50363338e-01, 2.73371905e-01],
#           [3.23740035e-01, 4.67153043e-01, 2.61117488e-01]],
#
#          [[8.29564929e-01, 9.27604139e-01, 6.68106616e-01],
#           [7.81770825e-01, 8.76776934e-01, 6.06066167e-01],
#           [8.28033090e-01, 9.15992618e-01, 6.23529434e-01],
#           ...,
#           [4.34865206e-01, 5.00919104e-01, 3.78278196e-01],
#           [2.67892152e-01, 3.83272052e-01, 2.10079655e-01],
#           [3.02726716e-01, 4.46139693e-01, 2.43903190e-01]]],
#
#
#         [[[7.05882370e-01, 7.21568644e-01, 7.25490212e-01],
#           [7.05882370e-01, 7.21568644e-01, 7.25490212e-01],
#           [7.05882370e-01, 7.21568644e-01, 7.25490212e-01],
#           ...,
#           [7.13725507e-01, 7.29411781e-01, 7.41176486e-01],
#           [7.13725507e-01, 7.29411781e-01, 7.41176486e-01],
#           [7.13725507e-01, 7.29411781e-01, 7.41176486e-01]],
#
#          [[7.05882370e-01, 7.21568644e-01, 7.25490212e-01],
#           [7.05882370e-01, 7.21568644e-01, 7.25490212e-01],
#           [7.05882370e-01, 7.21568644e-01, 7.25490212e-01],
#           ...,
#           [7.13725507e-01, 7.29411781e-01, 7.41176486e-01],
#           [7.13725507e-01, 7.29411781e-01, 7.41176486e-01],
#           [7.13725507e-01, 7.29411781e-01, 7.41176486e-01]],
#
#          [[7.05882370e-01, 7.21568644e-01, 7.25490212e-01],
#           [7.05882370e-01, 7.21568644e-01, 7.25490212e-01],
#           [7.05882370e-01, 7.21568644e-01, 7.25490212e-01],
#           ...,
#           [7.13725507e-01, 7.29411781e-01, 7.41176486e-01],
#           [7.13725507e-01, 7.29411781e-01, 7.41176486e-01],
#           [7.13725507e-01, 7.29411781e-01, 7.41176486e-01]],
#
#          ...,
#
#          [[3.24984670e-01, 3.60278785e-01, 3.87729794e-01],
#           [3.57876331e-01, 3.93170446e-01, 4.20621425e-01],
#           [3.83130699e-01, 4.18424815e-01, 4.45875794e-01],
#           ...,
#           [1.00321688e-01, 1.47380516e-01, 1.94439337e-01],
#           [1.00540966e-01, 1.47599787e-01, 1.94658622e-01],
#           [1.05667889e-01, 1.52726710e-01, 1.99785545e-01]],
#
#          [[2.84834564e-01, 3.20128679e-01, 3.47579658e-01],
#           [3.33723962e-01, 3.69018078e-01, 3.96469057e-01],
#           [3.61389399e-01, 3.96683514e-01, 4.24134493e-01],
#           ...,
#           [1.05882354e-01, 1.52941182e-01, 2.00000003e-01],
#           [1.05721511e-01, 1.52780324e-01, 1.99839160e-01],
#           [1.01960786e-01, 1.49019614e-01, 1.96078435e-01]],
#
#          [[2.90196091e-01, 3.25490206e-01, 3.52941185e-01],
#           [3.39085490e-01, 3.74379605e-01, 4.01830584e-01],
#           [3.66750926e-01, 4.02045041e-01, 4.29496020e-01],
#           ...,
#           [1.05882354e-01, 1.52941182e-01, 2.00000003e-01],
#           [1.05721511e-01, 1.52780324e-01, 1.99839160e-01],
#           [1.01960786e-01, 1.49019614e-01, 1.96078435e-01]]]],
#        dtype=float32),
#  array([0, 1, 1, 0, 1, 0, 1, 1, 0, 1, 1, 1, 1, 0, 1, 1, 1, 0, 1, 0, 0, 1,
#         0, 0, 0, 1, 1, 1, 1, 0, 1, 1]))

# %% [markdown]
# #split data

# %%
train_size = int(len(data)*.7)
val_size = int(len(data)*.2) #validation 
test_size = int(len(data)*.1)

# %%
train_size
# Out:
# 10

# %%
train = data.take(train_size)
val = data.skip(train_size).take(val_size)
test = data.skip(train_size).take(test_size)

# %% [markdown]
# #Build Model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Dropout

# %%
model = Sequential()

# %%
model.add(Conv2D(16, (3,3), 1, activation='relu', input_shape=(256,256,3)))
model.add(MaxPooling2D())
model.add(Conv2D(32, (3,3), 1, activation='relu'))
model.add(MaxPooling2D())
model.add(Conv2D(16, (3,3), 1, activation='relu'))
model.add(MaxPooling2D())
model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
model.compile('adam', loss=tf.losses.BinaryCrossentropy(), metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 254, 254, 16)      448
#
#  max_pooling2d (MaxPooling2D  (None, 127, 127, 16)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 125, 125, 32)      4640
#
#  max_pooling2d_1 (MaxPooling  (None, 62, 62, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 60, 60, 16)        4624
#
#  max_pooling2d_2 (MaxPooling  (None, 30, 30, 16)       0
#  2D)
#
#  flatten (Flatten)           (None, 14400)             0
#
#  dense (Dense)               (None, 256)               3686656
#
#  dense_1 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 3,696,625
# Trainable params: 3,696,625
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #Train

# %%
logdir='logs'

# %%
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=logdir)

# %%
hist = model.fit(train, epochs=20, validation_data=val, callbacks=[tensorboard_callback])
# Out:
# Epoch 1/20
# 10/10 [==============================] - 8s 631ms/step - loss: 1.1431 - accuracy: 0.4563 - val_loss: 0.6800 - val_accuracy: 0.5833
# Epoch 2/20
# 10/10 [==============================] - 7s 639ms/step - loss: 0.6891 - accuracy: 0.5344 - val_loss: 0.6683 - val_accuracy: 0.5833
# Epoch 3/20
# 10/10 [==============================] - 8s 664ms/step - loss: 0.6647 - accuracy: 0.5750 - val_loss: 0.6126 - val_accuracy: 0.5833
# Epoch 4/20
# 10/10 [==============================] - 8s 667ms/step - loss: 0.6165 - accuracy: 0.6656 - val_loss: 0.8208 - val_accuracy: 0.4375
# Epoch 5/20
# 10/10 [==============================] - 8s 701ms/step - loss: 0.5984 - accuracy: 0.6781 - val_loss: 0.5612 - val_accuracy: 0.7396
# Epoch 6/20
# 10/10 [==============================] - 8s 655ms/step - loss: 0.5947 - accuracy: 0.6906 - val_loss: 0.5760 - val_accuracy: 0.6771
# Epoch 7/20
# 10/10 [==============================] - 8s 671ms/step - loss: 0.5126 - accuracy: 0.7656 - val_loss: 0.4427 - val_accuracy: 0.8333
# Epoch 8/20
# 10/10 [==============================] - 7s 648ms/step - loss: 0.4229 - accuracy: 0.8375 - val_loss: 0.4058 - val_accuracy: 0.7917
# Epoch 9/20
# 10/10 [==============================] - 8s 672ms/step - loss: 0.3165 - accuracy: 0.9000 - val_loss: 0.2769 - val_accuracy: 0.9271
# Epoch 10/20
# 10/10 [==============================] - 8s 683ms/step - loss: 0.2408 - accuracy: 0.9312 - val_loss: 0.1409 - val_accuracy: 0.9688
# Epoch 11/20
# 10/10 [==============================] - 7s 653ms/step - loss: 0.2000 - accuracy: 0.9438 - val_loss: 0.1990 - val_accuracy: 0.9479
# Epoch 12/20
# 10/10 [==============================] - 8s 678ms/step - loss: 0.1745 - accuracy: 0.9688 - val_loss: 0.1780 - val_accuracy: 0.9583
# Epoch 13/20
# 10/10 [==============================] - 8s 690ms/step - loss: 0.1482 - accuracy: 0.9625 - val_loss: 0.0926 - val_accuracy: 0.9792
# Epoch 14/20
# 10/10 [==============================] - 7s 630ms/step - loss: 0.0734 - accuracy: 0.9844 - val_loss: 0.0713 - val_accuracy: 0.9896
# Epoch 15/20
# 10/10 [==============================] - 7s 642ms/step - loss: 0.0567 - accuracy: 0.9937 - val_loss: 0.0232 - val_accuracy: 1.0000
# Epoch 16/20
# 10/10 [==============================] - 7s 633ms/step - loss: 0.0340 - accuracy: 0.9937 - val_loss: 0.0807 - val_accuracy: 0.9688
# Epoch 17/20
# 10/10 [==============================] - 7s 637ms/step - loss: 0.0254 - accuracy: 0.9937 - val_loss: 0.0245 - val_accuracy: 0.9896
# Epoch 18/20
# 10/10 [==============================] - 7s 626ms/step - loss: 0.0171 - accuracy: 0.9969 - val_loss: 0.0225 - val_accuracy: 1.0000
# Epoch 19/20
# 10/10 [==============================] - 7s 642ms/step - loss: 0.0228 - accuracy: 0.9969 - val_loss: 0.0078 - val_accuracy: 1.0000
# Epoch 20/20
# 10/10 [==============================] - 7s 644ms/step - loss: 0.0068 - accuracy: 1.0000 - val_loss: 0.0048 - val_accuracy: 1.0000

# %% [markdown]
# #plot performance

# %%
fig = plt.figure()
plt.plot(hist.history['loss'], color='teal', label='loss')
plt.plot(hist.history['val_loss'], color='orange', label='val_loss')
fig.suptitle('Loss', fontsize=20)
plt.legend(loc="upper left")
plt.show()

# %%
fig = plt.figure()
plt.plot(hist.history['accuracy'], color='teal', label='accuracy')
plt.plot(hist.history['val_accuracy'], color='orange', label='val_accuracy')
fig.suptitle('Accuracy', fontsize=20)
plt.legend(loc="upper left")
plt.show()

# %% [markdown]
# #Evaluate

# %%
from tensorflow.keras.metrics import Precision, Recall, BinaryAccuracy

# %%
pre = Precision()
re = Recall()
acc = BinaryAccuracy()

# %%
for batch in test.as_numpy_iterator(): 
    X, y = batch
    yhat = model.predict(X)
    pre.update_state(y, yhat)
    re.update_state(y, yhat)
    acc.update_state(y, yhat)
# Out:
# 1/1 [==============================] - 0s 182ms/step

# %%
print(pre.result(), re.result(), acc.result())
# Out:
# tf.Tensor(1.0, shape=(), dtype=float32) tf.Tensor(1.0, shape=(), dtype=float32) tf.Tensor(1.0, shape=(), dtype=float32)

# %% [markdown]
# #Test

# %%
import cv2

# %%
img = cv2.imread(r'dog2.png')
plt.imshow(img)
plt.show()

# %%
resize = tf.image.resize(img, (256,256))
plt.imshow(resize.numpy().astype(int))
plt.show()

# %%
yhat_2 = model.predict(np.expand_dims(resize/255, 0))
# Out:
# 1/1 [==============================] - 0s 25ms/step

# %%
yhat_2
# Out:
# array([[0.91617304]], dtype=float32)

# %%
if yhat_2 > 0.5: 
    print(f'Predicted class is Dog')
else:
    print(f'Predicted class is Cat')
# Out:
# Predicted class is Dog
